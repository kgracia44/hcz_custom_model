# %% [markdown]
# # INFORMATION FROM HCZ:
#
# ### Here is a link to a map of our “Zone” https://hcz.org/zone-map/
#
# - Ignore the sites plotted on the map and rather focus on the shaded blocks.
# - The [census] blocks look promising, please use the Zone map to identify which blocks to focus in on.
# - This does not include East Harlem.
#
# ### Our challenges at HCZ:
#
# 1) finding data on population and demographic changes in the Zone, since it’s not an area of land that maps perfectly into any tract, block group, school district, etc.
#    -- Though the ability to look at specific blocks does looks promising.
#
# 2) Often times we have to make educated guesses based on the information available,
#
# ### Specific question we are looking to answer:
#
# How many babies are born each year who reside in the Zone?
#
# - We would like this information for the past 5 years.
#
# - If possible, we’d want to know how many of the babies are to first time parents, though that is probably impossible to find out.

# %% [markdown]
# --------------------------------------------------------------------------
# #### Minimum ask: Find better matching data
# #### Ideal ask: Build a model to approximate the number of children born each year in the Zone. Past 5 years.
#
# - Focus on the shaded blocks in the Zone map to identify which blocks to focus in on.
# --------------------------------------------------------------------------
# ##### Number of the babies that are to first time parents:
#
# - Perhaps can use rough estimate: If you know or have some average for age of first time moms in zone area, you can extrapolate using data from this: https://censusreporter.org/profiles/79500US3603803-nycmanhattan-community-district-10central-harlem-puma-ny/

# %% [markdown]
# ## Notes:
#
# - The only (publicly) available data over number of births/birthrates that I could find for NYC neighborhoods was from the NYC Department of Health and Mental Hygeine, Bureau of Vital Statistics
# - With the goal of finding better-matching data to determine the number of children born each year in the Zone (minimum: past 5 years), the closest data available to the geographic region of interest was data for Community District 10 and Census Tract Data.
# - See Demographic Comparison PDF for a comparison of demographics and blocks within the Zone and Community District 10
# - Key difference between data sets for Community District 10 and Census Tracts:
#     - Community District: Single year aggregate counts (2000 - 2014; 15 data sets available)
#     - Census Tract: Aggregated 5 year counts (2000 - 2004, 2002 - 2006, 2004 - 2008, 2006 - 2010, 2010 - 2014; 5 data sets available)
# - Because there is already an existing birthrates model available (for approximating # of births) in Community District 10 (model can be found here: https://a816-healthpsi.nyc.gov/epiquery/Birth/index.html), the focus will be on developing a custom model for the Zone using data for census tracts that fall into the Zone. Because data is limited and based on 5 year aggregates, model will be 'rough'.
# - The following census tracts (GEOIDs) will be used to narrow data set to the Zone:
#     - 36061019000
#     - 36061019800
#     - 36061020000
#     - 36061020800
#     - 36061021000
#     - 36061021200
#     - 36061021400
#     - 36061022000
#     - 36061022200
#     - 36061022400
#     - 36061022600

# %%
# importing needed libraries

import csv
import time
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LassoCV, LassoLarsCV, LassoLarsIC


# %matplotlib inline

# %% [markdown]
# #### Data sets from vital statistics NYC Dept of Health and Mental Hygeine
# - Citation:
# New York City Department of Health and Mental Hygiene, Bureau of Vital Statistics. Birth Micro SAS Datasets 2000-2014, distributed by Bureau of Vital Statistics, December 1, 2017. https://www1.nyc.gov/site/doh/data/data-sets/vital-statistics-birth-micro-sas-datasets.page
#
#
# - Data Dictionary: https://www1.nyc.gov/assets/doh/downloads/pdf/vs/vs-micro-sas-birth%20datasets-descriptions.pdf
#
# Name of data files:
#
# - tractall_1014.sas7bdat
# - tractall_0610.sas7bdat
# - tractall_0408.sas7bdat
# - tractall_0206.sas7bdat
# - tractall_0004.sas7bdat

# %%
# Making sure the files can be read...

# from sas7bdat import SAS7BDAT
# with SAS7BDAT('tractall_1014.sas7bdat') as f:
#     for row in f:
#         print (row)

# %%
# Creating pandas dataframe for data, starting with data for 2010 - 2014

from sas7bdat import SAS7BDAT
with SAS7BDAT('tractall_1014.sas7bdat') as f:
    df10_14 = f.to_data_frame()

# %%
# adding column to identify period (timeframe) of data

# df10_14['pd'] = 1014
df10_14['pd'] = 5

df10_14.head()
# Out:
#        tract  birthtot age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  \
# 0  1000201.0     202.0    None      NaN      6.0     47.0     66.0     46.0
# 1  1000202.0     388.0    None      NaN     18.0     62.0     96.0    103.0
# 2  1000600.0     852.0    None      5.0     22.0    145.0    307.0    234.0
# 3  1000700.0     551.0    None      NaN      NaN      9.0     77.0    259.0
# 4  1000800.0    1130.0    None      NaN      7.0    187.0    472.0    283.0
#
#    age7tot  age8tot ...  mth1tot  mth2tot  mth3tot  mth4tot  pob1tot  pob2tot  \
# 0     29.0      NaN ...    145.0      NaN     28.0     24.0      NaN    140.0
# 1     82.0     25.0 ...    262.0     14.0     82.0     29.0      NaN    306.0
# 2    114.0     22.0 ...    617.0     13.0    138.0     79.0      NaN    690.0
# 3    158.0     43.0 ...    357.0      6.0    145.0     42.0      NaN    546.0
# 4    145.0     30.0 ...    771.0     23.0    197.0    116.0      NaN   1031.0
#
#    pob3tot  pob4tot  pob5tot  pd
# 0     62.0      NaN      NaN   5
# 1     79.0      NaN      NaN   5
# 2    160.0      NaN      NaN   5
# 3      NaN      NaN      NaN   5
# 4     99.0      NaN      NaN   5
#
# [5 rows x 85 columns]

# %%
# Repeating the previous 2 steps for all data sets (total of 5 data sets = 5 dataframes)

from sas7bdat import SAS7BDAT
with SAS7BDAT('tractall_0610.sas7bdat') as f:
    df06_10 = f.to_data_frame()
    
# df06_10['pd'] = 610
df06_10['pd'] = 4

df06_10.head()
# Out:
#        tract  birthtot  age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  \
# 0  1000201.0     272.0      NaN      NaN      7.0     67.0    103.0     65.0
# 1  1000202.0     421.0      NaN      6.0     13.0     81.0    117.0    105.0
# 2  1000600.0    1223.0      NaN      8.0     24.0    269.0    511.0    274.0
# 3  1000700.0     355.0      NaN      NaN      NaN      8.0     43.0    182.0
# 4  1000800.0    1722.0      NaN      NaN     12.0    438.0    695.0    397.0
#
#    age7tot  age8tot ...  mth1tot  mth2tot  mth3tot  mth4tot  pob1tot  pob2tot  \
# 0     23.0      NaN ...    205.0      NaN     35.0     27.0      NaN    171.0
# 1     76.0     22.0 ...    305.0      9.0     65.0     40.0      NaN    309.0
# 2    108.0     29.0 ...    935.0     11.0    169.0     96.0      NaN    917.0
# 3    100.0     19.0 ...    224.0      NaN    106.0     20.0      NaN    349.0
# 4    144.0     31.0 ...   1292.0     17.0    275.0    117.0      NaN   1464.0
#
#    pob3tot  pob4tot  pob5tot  pd
# 0    101.0      NaN      NaN   4
# 1    110.0      NaN      NaN   4
# 2    304.0      NaN      NaN   4
# 3      NaN      NaN      NaN   4
# 4    255.0      NaN      NaN   4
#
# [5 rows x 86 columns]

# %%
from sas7bdat import SAS7BDAT
with SAS7BDAT('tractall_0408.sas7bdat') as f:
    df04_08 = f.to_data_frame()
    
# df04_08['pd'] = 408
df04_08['pd'] = 3

df04_08.head()
# Out:
#        tract  birthtot  age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  \
# 0  1000201.0     276.0      NaN      6.0      8.0     73.0    109.0     62.0
# 1  1000202.0     436.0      NaN     12.0     17.0     92.0    113.0    103.0
# 2  1000600.0    1370.0      NaN     11.0     37.0    331.0    557.0    281.0
# 3  1000700.0     204.0      NaN      NaN      NaN      6.0     27.0     99.0
# 4  1000800.0    1930.0      NaN      NaN     17.0    532.0    780.0    426.0
#
#    age7tot  age8tot ...  mth1tot  mth2tot  mth3tot  mth4tot  pob1tot  pob2tot  \
# 0     16.0      NaN ...    220.0      NaN     31.0     21.0      NaN    169.0
# 1     75.0     23.0 ...    321.0     11.0     63.0     40.0      NaN    299.0
# 2    121.0     30.0 ...   1071.0     12.0    176.0    108.0      NaN    995.0
# 3     58.0     12.0 ...    128.0      NaN     63.0      9.0      NaN    199.0
# 4    146.0     24.0 ...   1535.0     10.0    268.0    113.0      NaN   1621.0
#
#    pob3tot  pob4tot  pob5tot  pd
# 0    106.0      NaN      NaN   3
# 1    134.0      NaN      NaN   3
# 2    373.0      NaN      NaN   3
# 3      NaN      NaN      NaN   3
# 4    304.0      NaN      NaN   3
#
# [5 rows x 86 columns]

# %%
from sas7bdat import SAS7BDAT
with SAS7BDAT('tractall_0206.sas7bdat') as f:
    df02_06 = f.to_data_frame()
    
# df02_06['pd'] = 206
df02_06['pd'] = 2

df02_06.head()
# Out:
#        tract  birthtot  age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  \
# 0  1000201.0     268.0      NaN      7.0     10.0     72.0    106.0     54.0
# 1  1000202.0     441.0      NaN      8.0     22.0     94.0    118.0    100.0
# 2  1000600.0    1371.0      NaN     11.0     43.0    344.0    555.0    257.0
# 3  1000700.0      90.0      NaN      NaN      NaN      NaN     19.0     37.0
# 4  1000800.0    1777.0      NaN      NaN     28.0    489.0    725.0    378.0
#
#    age7tot  age8tot ...  mth1tot  mth2tot  mth3tot  mth4tot  pob1tot  pob2tot  \
# 0     16.0      NaN ...    219.0      NaN     29.0     17.0      NaN    169.0
# 1     77.0     22.0 ...    328.0     15.0     66.0     32.0      NaN    289.0
# 2    132.0     27.0 ...   1104.0     17.0    164.0     82.0      NaN    954.0
# 3     25.0      5.0 ...     58.0      NaN     27.0      NaN      NaN     87.0
# 4    133.0     18.0 ...   1480.0     12.0    207.0     76.0      NaN   1464.0
#
#    pob3tot  pob4tot  pob5tot  pd
# 0     97.0      NaN      NaN   2
# 1    151.0      NaN      NaN   2
# 2    410.0      NaN      NaN   2
# 3      NaN      NaN      NaN   2
# 4    310.0      NaN      NaN   2
#
# [5 rows x 100 columns]

# %%
from sas7bdat import SAS7BDAT
with SAS7BDAT('tractall_0004.sas7bdat') as f:
    df00_04 = f.to_data_frame()
    
# df00_04['pd'] = 4000
df00_04['pd'] = 1

df00_04.head()
# Out:
#        tract  birthtot  age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  \
# 0  1000201.0     257.0      NaN      7.0     13.0     73.0     92.0     53.0
# 1  1000202.0     421.0      NaN     10.0     22.0     91.0    126.0     94.0
# 2  1000600.0    1327.0      NaN     10.0     42.0    335.0    512.0    248.0
# 3  1000800.0    1580.0      NaN      NaN     37.0    407.0    624.0    364.0
# 4  1000900.0      82.0      NaN      NaN      NaN      5.0     16.0     34.0
#
#    age7tot  age8tot ...  mth1tot  mth2tot  mth3tot  mth4tot  pob1tot  pob2tot  \
# 0     17.0      NaN ...    217.0      NaN     27.0      8.0      NaN    160.0
# 1     64.0     14.0 ...    316.0     11.0     66.0     28.0      NaN    280.0
# 2    154.0     23.0 ...   1092.0     22.0    154.0     57.0      NaN    928.0
# 3    128.0     15.0 ...   1361.0     12.0    153.0     51.0      NaN   1281.0
# 4     23.0      NaN ...     62.0      NaN     13.0      5.0      NaN     78.0
#
#    pob3tot  pob4tot  pob5tot  pd
# 0     94.0      NaN      NaN   1
# 1    140.0      NaN      NaN   1
# 2    393.0      NaN      NaN   1
# 3    294.0      NaN      NaN   1
# 4      NaN      NaN      NaN   1
#
# [5 rows x 100 columns]

# %%
# Concatenating all 5 dataframes for one dataset 
# Although the timeframes overlap for 4 out of 5 data sets, final model will approximate births for 5-year periods

frames = [df10_14, df06_10, df04_08, df02_06, df00_04]

result = pd.concat(frames)

# %%
# Creating list of census tracts that fall within the Zone (cleanly) in order to filter data set

zone_census_tracts = [1019000, 1019800, 1020000, 1020800, 1021000, 1021200, \
                      1021400, 1022000, 1022200, 1022400, 1022600]

# %%
# Filtering dataset 

raw_data_vsBirths = result[result['tract'].isin(zone_census_tracts)]
raw_data_vsBirths
# Out:
#      age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  age7tot  age8tot  \
# 184      NaN      NaN     10.0     42.0     39.0     68.0     72.0     27.0
# 193      NaN      NaN      NaN     22.0     16.0     38.0     22.0     13.0
# 195      NaN      NaN      8.0     24.0     32.0     46.0     32.0     10.0
# 201      NaN      NaN     16.0     52.0     66.0     70.0     53.0     18.0
# 203      NaN     11.0     27.0     77.0    110.0     97.0     65.0     10.0
# 205      NaN      NaN      8.0     30.0     56.0     79.0     56.0     12.0
# 207      NaN      NaN      8.0     28.0     38.0     37.0     29.0      NaN
# 212      NaN      NaN     16.0     88.0     89.0    137.0     89.0     37.0
# 214      NaN      NaN     18.0     36.0     38.0     45.0     68.0     12.0
# 217      NaN     15.0     32.0    123.0    115.0    101.0     56.0     17.0
# 219      NaN      NaN      9.0     50.0     58.0     76.0     51.0     18.0
# 184      NaN      7.0     13.0     44.0     42.0     56.0     53.0     14.0
# 192      NaN      NaN      NaN     11.0     11.0     25.0     13.0      NaN
# 194      NaN      NaN      8.0      6.0     33.0     45.0     26.0     13.0
# 203      NaN      NaN     17.0     46.0     74.0     78.0     54.0     21.0
# 205      NaN     23.0     40.0     95.0     97.0     71.0     65.0     17.0
# 207      NaN      5.0     17.0     43.0     44.0     66.0     35.0     13.0
# 209      NaN      6.0      7.0     25.0     44.0     31.0     24.0     10.0
# 215      NaN     12.0     15.0     91.0     88.0    121.0     82.0     35.0
# 212      NaN       11.0     ...             NaN         NaN         NaN
# 214      NaN        NaN     ...             NaN         NaN         NaN
# 217      NaN        NaN     ...             NaN         NaN         NaN
# 219      NaN        NaN     ...             NaN         NaN         NaN
# 184      NaN        5.0     ...             NaN         NaN         NaN
# 192      NaN        NaN     ...             NaN         NaN         NaN
# 194      NaN        NaN     ...             NaN         NaN         NaN
# 203      NaN        NaN     ...             NaN         NaN         NaN
# 205      NaN        NaN     ...             NaN         NaN         NaN
# 207      NaN        NaN     ...             NaN         NaN         NaN
# 209      NaN        NaN     ...             NaN         NaN         NaN
# 215      NaN        6.0     ...             NaN         NaN         NaN
# 218      NaN        NaN     ...             NaN         NaN         NaN
# 221      NaN        NaN     ...             NaN         NaN         NaN
# 223      5.0        NaN     ...             NaN         NaN         NaN
# 186      NaN        NaN     ...             NaN         NaN         NaN
# 194      NaN        NaN     ...             NaN         NaN         NaN
# 196      NaN        NaN     ...             NaN         NaN         NaN
# 205      NaN        NaN     ...             NaN         NaN         NaN
# 208      NaN        NaN     ...             NaN         NaN         NaN
# 210      NaN        NaN     ...             NaN         NaN         NaN
# 212      NaN        NaN     ...             NaN         NaN         NaN
# 218      NaN        8.0     ...             NaN         NaN         NaN
# 220      NaN        NaN     ...             NaN         NaN         NaN
# 223      NaN        NaN     ...             NaN         NaN         NaN
# 225      NaN        NaN     ...             NaN         NaN         NaN
# 185      NaN        NaN     ...            36.0        10.0         NaN
# 193      NaN        NaN     ...            13.0         6.0         NaN
# 195      NaN        NaN     ...            33.0        17.0         5.0
# 204      NaN        NaN     ...            66.0        35.0         NaN
# 207      NaN        NaN     ...            73.0        23.0         NaN
# 209      NaN        NaN     ...            30.0        12.0         NaN
# 211      NaN        NaN     ...            22.0        15.0         NaN
# 217      NaN        6.0     ...            93.0        35.0         8.0
# 219      NaN        NaN     ...            34.0        19.0         NaN
# 222      NaN        NaN     ...           118.0        44.0         8.0
# 224      NaN        NaN     ...            69.0        25.0        13.0
# 184      NaN        NaN     ...            38.0        11.0         NaN
# 192      NaN        NaN     ...            15.0         8.0         5.0
# 194      NaN        NaN     ...            31.0        18.0         6.0
# 203      NaN        NaN     ...            76.0        29.0         6.0
# 206      NaN        NaN     ...            81.0        32.0         8.0
# 208      NaN        NaN     ...            36.0        16.0         NaN
# 210      NaN        NaN     ...            26.0         9.0         NaN
# 216      NaN        NaN     ...            92.0        48.0         7.0
# 218      NaN        NaN     ...            38.0        18.0         NaN
# 221      NaN        NaN     ...           117.0        44.0         8.0
# 223      NaN        NaN     ...            71.0        27.0        13.0
#
#      sex1tot  sex2tot      tract  weight1tot  weight2tot  weight3tot  \
# 184    136.0    130.0  1019000.0         NaN         NaN         NaN
# 193     61.0     55.0  1019800.0         NaN         NaN         NaN
# 195     78.0     75.0  1020000.0         NaN         NaN         NaN
# 201    133.0    147.0  1020800.0         NaN         NaN         NaN
# 203    220.0    178.0  1021000.0         NaN         NaN         NaN
# 205    107.0    137.0  1021200.0         NaN         NaN         NaN
# 207     75.0     67.0  1021400.0         NaN         NaN         NaN
# 212    230.0    232.0  1022000.0         NaN         NaN         NaN
# 214    106.0    117.0  1022200.0         NaN         NaN         NaN
# 217    225.0    234.0  1022400.0         NaN         NaN         NaN
# 219    135.0    128.0  1022600.0         NaN         NaN         NaN
# 184    130.0    103.0  1019000.0         NaN         NaN         NaN
# 192     29.0     37.0  1019800.0         NaN         NaN         NaN
# 194     65.0     66.0  1020000.0         NaN         NaN         NaN
# 203    145.0    150.0  1020800.0         NaN         NaN         NaN
# 205    213.0    195.0  1021000.0         NaN         NaN         NaN
# 207    106.0    118.0  1021200.0         NaN         NaN         NaN
# 209     72.0     77.0  1021400.0         NaN         NaN         NaN
# 215    227.0    221.0  1022000.0         NaN         NaN         NaN
# 218     96.0    107.0  1022200.0         NaN         NaN         NaN
# 221    237.0    232.0  1022400.0         NaN         NaN         NaN
# 223    123.0    126.0  1022600.0         NaN         NaN         NaN
# 186     92.0     91.0  1019000.0         NaN         NaN         NaN
# 194     30.0     43.0  1019800.0         NaN         NaN         NaN
# 196     69.0     67.0  1020000.0         NaN         NaN         NaN
# 205    151.0    143.0  1020800.0         NaN         NaN         NaN
# 208    200.0    208.0  1021000.0         NaN         NaN         NaN
# 210     88.0    104.0  1021200.0         NaN         NaN         NaN
# 212     65.0     83.0  1021400.0         NaN         NaN         NaN
# 218    216.0    218.0  1022000.0         NaN         NaN         NaN
# 220     87.0     99.0  1022200.0         NaN         NaN         NaN
# 223    235.0    239.0  1022400.0         NaN         NaN         NaN
# 225    138.0    116.0  1022600.0         NaN         NaN         NaN
# 185     66.0     84.0  1019000.0         7.0        60.0        29.0
# 193     44.0     46.0  1019800.0         7.0        35.0        22.0
# 195     83.0     76.0  1020000.0         8.0        79.0        30.0
# 204    171.0    146.0  1020800.0        24.0       131.0        73.0
# 207    201.0    173.0  1021000.0        17.0       137.0        97.0
# 209     83.0    102.0  1021200.0        11.0        84.0        42.0
# 211     66.0     66.0  1021400.0         5.0        62.0        35.0
# 217    221.0    212.0  1022000.0        23.0       195.0       105.0
# 219     91.0     87.0  1022200.0         NaN        84.0        45.0
# 222    231.0    234.0  1022400.0        26.0       208.0       111.0
# 224    140.0    150.0  1022600.0        23.0       111.0        66.0
# 184     67.0     75.0  1019000.0         5.0        56.0        27.0
# 192     46.0     50.0  1019800.0         6.0        39.0        23.0
# 194     94.0     69.0  1020000.0         9.0        81.0        29.0
# 203    178.0    145.0  1020800.0        22.0       138.0        82.0
# 206    207.0    182.0  1021000.0        20.0       149.0        97.0
# 208     88.0    105.0  1021200.0        13.0        70.0        48.0
# 210     66.0     62.0  1021400.0         6.0        51.0        34.0
# 216    230.0    211.0  1022000.0        21.0       200.0        98.0
# 218     93.0    105.0  1022200.0        10.0        93.0        47.0
# 221    239.0    259.0  1022400.0        29.0       216.0       107.0
# 223    131.0    156.0  1022600.0        21.0       110.0        68.0
#
#      weight4tot
# 184         NaN
# 193         NaN
# 195         NaN
# 201         NaN
# 203         NaN
# 205         NaN
# 207         NaN
# 212         NaN
# 214         NaN
# 217         NaN
# 219         NaN
# 184         NaN
# 192         NaN
# 194         NaN
# 203         NaN
# 205         NaN
# 207         NaN
# 209         NaN
# 215         NaN
# 218         NaN
# 221         NaN
# 223         NaN
# 186         NaN
# 194         NaN
# 196         NaN
# 205         NaN
# 208         NaN
# 210         NaN
# 212         NaN
# 218         NaN
# 220         NaN
# 223         NaN
# 225         NaN
# 185        46.0
# 193        21.0
# 195        38.0
# 204        82.0
# 207       114.0
# 209        44.0
# 211        28.0
# 217       100.0
# 219        38.0
# 222       103.0
# 224        85.0
# 184        46.0
# 192        23.0
# 194        36.0
# 203        70.0
# 206       114.0
# 208        56.0
# 210        35.0
# 216       110.0
# 218        37.0
# 221       130.0
# 223        80.0
#
# [55 rows x 100 columns]

# %%
# Conducting quick scan over full data set

with pd.option_context('display.max_rows', 2000, 'display.max_columns', 100):
   print(raw_data_vsBirths)
# Out:
#      age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  age7tot  age8tot  \
# 184      NaN      NaN     10.0     42.0     39.0     68.0     72.0     27.0
# 193      NaN      NaN      NaN     22.0     16.0     38.0     22.0     13.0
# 195      NaN      NaN      8.0     24.0     32.0     46.0     32.0     10.0
# 201      NaN      NaN     16.0     52.0     66.0     70.0     53.0     18.0
# 203      NaN     11.0     27.0     77.0    110.0     97.0     65.0     10.0
# 205      NaN      NaN      8.0     30.0     56.0     79.0     56.0     12.0
# 207      NaN      NaN      8.0     28.0     38.0     37.0     29.0      NaN
# 212      NaN      NaN     16.0     88.0     89.0    137.0     89.0     37.0
# 214      NaN      NaN     18.0     36.0     38.0     45.0     68.0     12.0
# 217      NaN     15.0     32.0    123.0    115.0    101.0     56.0     17.0
# 219      NaN      NaN      9.0     50.0     58.0     76.0     51.0     18.0
# 184      NaN      7.0     13.0     44.0     42.0     56.0     53.0     14.0
# 192      NaN      NaN      NaN     11.0     11.0     25.0     13.0      NaN
# 194      NaN      NaN      8.0      6.0     33.0     45.0     26.0     13.0
# 203      NaN      NaN     17.0     46.0     74.0     78.0     54.0     21.0
# 205      NaN     23.0     40.0     95.0     97.0     71.0     65.0     17.0
# 207      NaN      5.0     17.0     43.0     44.0     66.0     35.0     13.0
# 209      NaN      6.0      7.0     25.0     44.0     31.0     24.0     10.0
# 215      NaN     12.0     15.0     91.0     88.0    121.0     82.0     35.0
# 218      NaN      NaN     14.0     35.0     42.0     52.0     35.0     21.0
# 221      NaN     21.0     34.0    143.0    109.0     84.0     52.0     22.0
# 223      NaN      NaN     21.0     60.0     51.0     65.0     34.0     10.0
# 186      NaN      8.0     15.0     32.0     43.0     28.0     47.0      7.0
# 194      NaN      NaN      NaN      8.0     24.0     24.0     10.0      NaN
# 196      NaN      NaN      8.0     14.0     27.0     42.0     31.0     14.0
# 205      NaN      NaN     19.0     60.0     79.0     71.0     41.0     21.0
# 208      NaN     20.0     37.0     91.0     96.0     74.0     70.0     18.0
# 210      NaN      6.0     14.0     35.0     39.0     44.0     36.0     15.0
# 212      NaN      6.0      NaN     27.0     37.0     39.0     26.0      8.0
# 218      NaN     13.0     17.0     80.0    110.0    128.0     58.0     24.0
# 220      NaN      NaN     10.0     34.0     43.0     42.0     37.0     19.0
# 223      NaN     31.0     44.0    133.0    107.0     83.0     52.0     21.0
# 225      NaN      NaN     25.0     55.0     66.0     60.0     35.0      5.0
# 185      NaN      6.0     11.0     31.0     34.0     19.0     37.0      9.0
# 193      NaN      NaN      NaN     12.0     22.0     32.0     17.0      NaN
# 195      NaN      NaN      8.0     28.0     41.0     41.0     29.0     10.0
# 204      NaN      NaN     22.0     67.0     82.0     78.0     43.0     21.0
# 207      NaN     24.0     30.0     83.0     83.0     76.0     62.0     14.0
# 209      NaN      5.0     12.0     38.0     41.0     38.0     36.0     13.0
# 211      NaN      6.0      6.0     22.0     35.0     36.0     20.0      7.0
# 217      NaN     16.0     21.0     75.0    119.0    129.0     54.0     17.0
# 219      NaN      NaN     10.0     31.0     46.0     36.0     36.0     15.0
# 222      NaN     34.0     48.0    131.0    108.0     74.0     48.0     21.0
# 224      NaN      8.0     24.0     77.0     74.0     65.0     38.0      NaN
# 184      NaN      NaN      9.0     39.0     30.0     21.0     33.0      6.0
# 192      NaN      NaN      5.0     18.0     23.0     32.0     15.0      NaN
# 194      NaN      6.0     11.0     38.0     42.0     35.0     28.0      NaN
# 203      NaN      9.0     19.0     69.0     79.0     78.0     52.0     15.0
# 206      NaN     18.0     32.0     84.0    101.0     89.0     51.0     13.0
# 208      NaN      NaN      7.0     33.0     53.0     50.0     37.0      8.0
# 210      NaN      NaN      9.0     25.0     34.0     32.0     19.0      5.0
# 216      NaN     14.0     27.0     99.0    114.0    115.0     54.0     16.0
# 218      NaN      5.0     10.0     40.0     53.0     41.0     35.0     13.0
# 221      NaN     28.0     52.0    143.0    114.0     88.0     54.0     18.0
# 223      NaN     10.0     25.0     72.0     66.0     64.0     45.0      5.0
#
#      age9tot  ancs10tot  ancs11tot  ancs12tot  ancs13tot  ancs14tot  \
# 184      6.0        NaN        5.0        NaN        NaN        6.0
# 193      NaN        NaN        NaN        NaN        NaN        NaN
# 195      NaN        NaN        NaN        NaN        NaN        NaN
# 201      NaN        NaN        5.0        NaN        NaN        NaN
# 203      NaN        NaN        NaN        NaN        NaN        NaN
# 205      NaN        NaN        5.0        NaN        NaN        NaN
# 207      NaN        NaN        NaN        NaN        NaN        NaN
# 212      NaN       11.0        8.0        NaN        NaN        6.0
# 214      NaN        NaN        NaN        NaN        NaN        NaN
# 217      NaN        NaN        NaN        NaN        NaN        NaN
# 219      NaN        NaN        NaN        NaN        NaN        NaN
# 184      NaN        5.0        NaN        NaN        NaN        NaN
# 192      NaN        NaN        NaN        NaN        NaN        NaN
# 194      NaN        NaN        NaN        NaN        NaN        NaN
# 203      NaN        NaN        NaN        NaN        NaN        NaN
# 205      NaN        NaN        NaN        NaN        NaN        NaN
# 207      NaN        NaN        6.0        NaN        NaN        7.0
# 209      NaN        NaN        NaN        NaN        NaN        NaN
# 215      NaN        6.0        8.0        NaN        NaN        NaN
# 218      NaN        NaN        NaN        NaN        NaN        NaN
# 221      NaN        NaN        NaN        NaN        NaN        NaN
# 223      5.0        NaN        NaN        NaN        NaN        NaN
# 186      NaN        NaN        NaN        NaN        NaN        NaN
# 194      NaN        NaN        NaN        NaN        NaN        NaN
# 196      NaN        NaN        NaN        NaN        NaN        NaN
# 205      NaN        NaN        5.0        NaN        NaN        NaN
# 208      NaN        NaN        NaN        NaN        NaN        NaN
# 210      NaN        NaN        NaN        NaN        NaN        NaN
# 212      NaN        NaN        NaN        NaN        NaN        NaN
# 218      NaN        8.0        7.0        NaN        NaN        NaN
# 220      NaN        NaN        NaN        NaN        NaN        NaN
# 223      NaN        NaN        NaN        NaN        NaN        NaN
# 225      NaN        NaN        5.0        NaN        NaN        NaN
# 185      NaN        NaN        NaN        NaN        NaN        NaN
# 193      NaN        NaN        NaN        NaN        NaN        NaN
# 195      NaN        NaN        NaN        NaN        NaN        NaN
# 204      NaN        NaN        7.0        NaN        NaN        NaN
# 207      NaN        NaN        NaN        NaN        NaN        NaN
# 209      NaN        NaN        NaN        NaN        NaN        NaN
# 211      NaN        NaN        NaN        NaN        NaN        NaN
# 217      NaN        6.0        5.0        NaN        NaN        5.0
# 219      NaN        NaN        NaN        NaN        NaN        NaN
# 222      NaN        NaN        NaN        NaN        NaN        NaN
# 224      NaN        NaN        7.0        NaN        NaN        NaN
# 184      NaN        NaN        NaN        NaN        NaN        NaN
# 192      NaN        NaN        NaN        NaN        NaN        NaN
# 194      NaN        NaN        NaN        NaN        NaN        NaN
# 203      NaN        NaN        6.0        NaN        NaN        NaN
# 206      NaN        NaN        NaN        NaN        NaN        NaN
# 208      NaN        NaN        NaN        NaN        NaN        NaN
# 210      NaN        NaN        NaN        NaN        NaN        NaN
# 216      NaN        NaN        6.0        NaN        NaN        NaN
# 218      NaN        NaN        NaN        NaN        NaN        NaN
# 221      NaN        NaN        6.0        NaN        NaN        NaN
# 223      NaN        NaN        NaN        NaN        NaN        NaN
#
#      ancs15tot  ancs1tot  ancs2tot  ancs3tot  ancs4tot  ancs5tot  ancs6tot  \
# 184        NaN      72.0      13.0      14.0       NaN       5.0       NaN
# 193        NaN      28.0       7.0       6.0       NaN       5.0       NaN
# 195        NaN      47.0       5.0       5.0       9.0       NaN       NaN
# 201        NaN     109.0      10.0      13.0       NaN       NaN       NaN
# 203        NaN     173.0      44.0      52.0       NaN       NaN       NaN
# 205        NaN     107.0       6.0      24.0       NaN       NaN       NaN
# 207        NaN      63.0       9.0       5.0       NaN       NaN       NaN
# 212        NaN     130.0      19.0      35.0       5.0       5.0       NaN
# 214        NaN      75.0      19.0       NaN       NaN       NaN       5.0
# 217        NaN     198.0      48.0      85.0       5.0       NaN       NaN
# 219        NaN      80.0      11.0      32.0       8.0       NaN       NaN
# 184        NaN      73.0      14.0       9.0       7.0       5.0       NaN
# 192        NaN      27.0       NaN       NaN       NaN       NaN       NaN
# 194        NaN      44.0       NaN       NaN       7.0       NaN       NaN
# 203        NaN     113.0      13.0      15.0       NaN       NaN       NaN
# 205        NaN     194.0      61.0      54.0       NaN       NaN       NaN
# 207        NaN     111.0      10.0      11.0       6.0       NaN       NaN
# 209        NaN      85.0       8.0       5.0       NaN       NaN       NaN
# 215        NaN     160.0      23.0      37.0       NaN       NaN       NaN
# 218        NaN      91.0      11.0       6.0       NaN       NaN       NaN
# 221        NaN     217.0      38.0      77.0      11.0       5.0       NaN
# 223        NaN     110.0      10.0      18.0       7.0       NaN       NaN
# 186        NaN      68.0      16.0       NaN       5.0       NaN       NaN
# 194        NaN      35.0       6.0       NaN       5.0       NaN       NaN
# 196        NaN      51.0       6.0       5.0      10.0       NaN       NaN
# 205        NaN     125.0      14.0       7.0       NaN       NaN       NaN
# 208        NaN     219.0      59.0      44.0       NaN       NaN       NaN
# 210        NaN     117.0      10.0       7.0       5.0       NaN       NaN
# 212        NaN      85.0       5.0       NaN       NaN       NaN       NaN
# 218        NaN     163.0      28.0      42.0       NaN       5.0       NaN
# 220        NaN      88.0      11.0       8.0       NaN       NaN       NaN
# 223        NaN     224.0      43.0      66.0      11.0      10.0       NaN
# 225        NaN     123.0      16.0      11.0      10.0       NaN       NaN
# 185        NaN      69.0      13.0       NaN       6.0       NaN       NaN
# 193        NaN      51.0       NaN       NaN       8.0       NaN       NaN
# 195        NaN      68.0       7.0       NaN      15.0       NaN       NaN
# 204        NaN     156.0      20.0       5.0       NaN       NaN       NaN
# 207        NaN     226.0      50.0      36.0       NaN       NaN       NaN
# 209        NaN     122.0       7.0       8.0       5.0       NaN       NaN
# 211        NaN      81.0       NaN       NaN       NaN       NaN       NaN
# 217        NaN     178.0      26.0      35.0       NaN       NaN       NaN
# 219        NaN      80.0      12.0       9.0       NaN       NaN       NaN
# 222        NaN     231.0      38.0      69.0      11.0       7.0       NaN
# 224        NaN     137.0      23.0      14.0      15.0       NaN       NaN
# 184        NaN      82.0       8.0       5.0       NaN       NaN       NaN
# 192        NaN      60.0       NaN       NaN       8.0       NaN       NaN
# 194        NaN      72.0       6.0       6.0      13.0       NaN       NaN
# 203        NaN     171.0      19.0       8.0       NaN       NaN       NaN
# 206        NaN     256.0      41.0      30.0       NaN       NaN       NaN
# 208        NaN     127.0       NaN       7.0       NaN       NaN       NaN
# 210        NaN      93.0       NaN       NaN       NaN       NaN       NaN
# 216        NaN     208.0      19.0      20.0       5.0       NaN       NaN
# 218        NaN      95.0      12.0       5.0       NaN       NaN       NaN
# 221        7.0     268.0      35.0      56.0       8.0       5.0       NaN
# 223        NaN     142.0      26.0      10.0      13.0       NaN       NaN
#
#      ancs7tot  ancs8tot  ancs9tot  ancs_oth_tot  apg1tot  apg2tot  apg3tot  \
# 184      23.0       NaN       NaN          94.0      NaN      NaN      6.0
# 193      12.0       NaN       NaN          29.0      NaN      NaN      6.0
# 195      12.0       NaN       NaN          47.0      NaN      NaN      NaN
# 201      14.0       NaN       NaN          98.0      5.0      NaN     15.0
# 203      20.0       NaN       NaN          74.0      6.0      5.0     20.0
# 205      13.0       NaN       NaN          65.0      NaN      NaN     13.0
# 207       6.0       NaN       NaN          48.0      NaN      NaN      6.0
# 212      28.0       8.0       NaN         158.0      NaN      7.0     34.0
# 214      23.0       NaN       NaN          71.0      NaN      NaN     14.0
# 217       7.0       NaN       NaN          92.0      NaN      6.0     28.0
# 219      19.0       5.0       NaN          77.0      NaN      NaN     13.0
# 184      18.0       NaN       NaN          78.0      NaN      NaN      NaN
# 192       NaN       NaN       NaN          24.0      NaN      NaN      NaN
# 194       9.0       NaN       NaN          47.0      NaN      NaN      7.0
# 203      11.0       NaN       NaN         118.0      5.0      NaN     17.0
# 205      12.0       NaN       NaN          51.0     11.0      NaN     27.0
# 207      15.0       NaN       NaN          44.0      NaN      NaN     14.0
# 209       NaN       NaN       NaN          30.0      NaN      NaN     11.0
# 215      20.0       NaN       6.0         148.0      9.0      NaN     18.0
# 218       5.0       NaN       NaN          69.0      NaN      NaN      8.0
# 221       5.0       NaN       NaN          91.0      6.0      7.0     36.0
# 223       6.0       NaN       NaN          74.0      5.0      NaN     11.0
# 186      10.0       NaN       NaN          64.0      NaN      NaN      NaN
# 194       NaN       NaN       NaN          20.0      NaN      NaN      5.0
# 196       5.0       NaN       NaN          50.0      NaN      NaN      8.0
# 205       9.0       NaN       NaN         122.0      5.0      5.0     22.0
# 208       5.0       NaN       NaN          60.0     10.0      5.0     24.0
# 210       7.0       NaN       NaN          32.0      NaN      NaN     13.0
# 212       NaN       NaN       NaN          39.0      NaN      NaN     10.0
# 218      12.0       6.0       7.0         135.0      NaN      NaN     21.0
# 220       NaN       NaN       NaN          60.0      NaN      NaN      9.0
# 223       NaN       NaN       NaN          99.0      7.0      5.0     44.0
# 225       NaN       NaN       NaN          70.0      5.0      8.0     16.0
# 185       NaN       NaN       NaN          45.0      NaN      NaN      6.0
# 193       NaN       NaN       NaN          18.0      NaN      NaN      5.0
# 195       NaN       NaN       NaN          57.0      NaN      NaN      7.0
# 204       NaN       NaN       NaN         118.0      NaN      7.0     31.0
# 207       NaN       NaN       NaN          52.0      6.0      7.0     19.0
# 209       NaN       NaN       NaN          32.0      5.0      NaN      9.0
# 211       NaN       NaN       NaN          36.0      NaN      NaN      8.0
# 217       6.0       NaN       8.0         145.0      NaN      NaN     25.0
# 219       5.0       NaN       NaN          58.0      NaN      NaN     13.0
# 222       NaN       NaN       NaN          94.0      7.0      NaN     42.0
# 224       NaN       NaN       NaN          80.0      5.0      8.0     13.0
# 184       NaN       NaN       NaN          29.0      NaN      NaN      8.0
# 192       NaN       NaN       NaN          16.0      NaN      NaN      NaN
# 194       NaN       NaN       NaN          55.0      NaN      NaN      9.0
# 203       NaN       NaN       NaN         112.0      7.0     10.0     33.0
# 206       5.0       NaN       NaN          47.0      NaN      6.0     16.0
# 208       NaN       NaN       NaN          36.0      NaN      NaN     12.0
# 210       NaN       NaN       NaN          22.0      NaN      NaN      8.0
# 216       NaN       NaN       8.0         152.0      NaN      6.0     28.0
# 218       5.0       NaN       NaN          63.0      NaN      NaN     27.0
# 221       NaN       NaN       NaN         103.0      9.0     10.0     31.0
# 223       NaN       NaN       NaN          76.0      5.0      8.0     15.0
#
#      apg4tot  apg5tot  birthtot  bpl10tot  bpl11tot  bpl12tot  bpl13tot  \
# 184    250.0      NaN     266.0       NaN       NaN       NaN       NaN
# 193    104.0      NaN     116.0       NaN       NaN       NaN       NaN
# 195    140.0      NaN     153.0       NaN       NaN       NaN       NaN
# 201    253.0      NaN     280.0       NaN       NaN       NaN       NaN
# 203    361.0      NaN     398.0       NaN       NaN       NaN       NaN
# 205    217.0      7.0     244.0       NaN       NaN       NaN       NaN
# 207    131.0      NaN     142.0       NaN       NaN       NaN       NaN
# 212    412.0      6.0     462.0       NaN       NaN       NaN       5.0
# 214    201.0      NaN     223.0       NaN       NaN       NaN       NaN
# 217    422.0      NaN     459.0       NaN       NaN       NaN       NaN
# 219    246.0      NaN     263.0       NaN       NaN       NaN       NaN
# 184    224.0      NaN     233.0       NaN       NaN       NaN       NaN
# 192     59.0      NaN      66.0       NaN       NaN       NaN       NaN
# 194    117.0      NaN     131.0       NaN       NaN       NaN       NaN
# 203    267.0      NaN     295.0       NaN       NaN       NaN       NaN
# 205    360.0      5.0     408.0       NaN       NaN       NaN       NaN
# 207    196.0      8.0     224.0       6.0       NaN       NaN       NaN
# 209    128.0      NaN     149.0       NaN       NaN       NaN       NaN
# 215    403.0     15.0     448.0       NaN       NaN       NaN       7.0
# 218    191.0      NaN     203.0       NaN       NaN       NaN       NaN
# 221    410.0      5.0     469.0       NaN       NaN       NaN       NaN
# 223    227.0      NaN     249.0       NaN       NaN       NaN       NaN
# 186    174.0      NaN     183.0       NaN       NaN       NaN       NaN
# 194     65.0      NaN      73.0       NaN       NaN       NaN       NaN
# 196    121.0      NaN     136.0       NaN       NaN       NaN       NaN
# 205    255.0      6.0     294.0       NaN       NaN       NaN       NaN
# 208    364.0      NaN     408.0       NaN       NaN       NaN       NaN
# 210    166.0      8.0     192.0       NaN       NaN       NaN       NaN
# 212    128.0      NaN     148.0       NaN       NaN       NaN       NaN
# 218    386.0     21.0     434.0       NaN       NaN       NaN       NaN
# 220    169.0      5.0     186.0       NaN       NaN       NaN       NaN
# 223    405.0     12.0     474.0       NaN       NaN       NaN       NaN
# 225    222.0      NaN     254.0       NaN       NaN       NaN       NaN
# 185    140.0      NaN     150.0       NaN       NaN       NaN       NaN
# 193     81.0      NaN      90.0       NaN       NaN       NaN       NaN
# 195    144.0      6.0     159.0       NaN       NaN       NaN       NaN
# 204    264.0      9.0     317.0       NaN       NaN       NaN       NaN
# 207    333.0      9.0     374.0       NaN       NaN       NaN       NaN
# 209    155.0     14.0     185.0       NaN       NaN       NaN       NaN
# 211    112.0      7.0     132.0       NaN       NaN       NaN       NaN
# 217    382.0     22.0     433.0       NaN       NaN       NaN       NaN
# 219    151.0      8.0     178.0       NaN       NaN       NaN       NaN
# 222    395.0     17.0     465.0       NaN       NaN       NaN       NaN
# 224    251.0     13.0     290.0       NaN       NaN       NaN       NaN
# 184    122.0      8.0     142.0       NaN       NaN       NaN       NaN
# 192     86.0      NaN      96.0       NaN       NaN       NaN       NaN
# 194    138.0     13.0     163.0       NaN       NaN       NaN       NaN
# 203    256.0     15.0     323.0       NaN       NaN       NaN       NaN
# 214   5     215.0       8.0      NaN    156.0     64.0      NaN      NaN
# 217   5     437.0      22.0      NaN    250.0    208.0      NaN      NaN
# 219   5     255.0       8.0      NaN    167.0     95.0      NaN      NaN
# 184   4     223.0      10.0      NaN    170.0     61.0      NaN      NaN
# 192   4      65.0       NaN      NaN     50.0     15.0      NaN      NaN
# 194   4     127.0       NaN      NaN     99.0     27.0      NaN      NaN
# 203   4     285.0      10.0      NaN    174.0    118.0      NaN      NaN
# 205   4     381.0      27.0      NaN    228.0    179.0      NaN      NaN
# 207   4     216.0       8.0      NaN    142.0     78.0      NaN      NaN
# 209   4     149.0       NaN      NaN     91.0     57.0      NaN      NaN
# 215   4     428.0      20.0      5.0    332.0    110.0      NaN      NaN
# 218   4     193.0      10.0      NaN    132.0     71.0      NaN      NaN
# 221   4     449.0      20.0      NaN    260.0    204.0      NaN      NaN
# 223   4     239.0      10.0      NaN    139.0    109.0      NaN      NaN
# 186   3     171.0      12.0      NaN    135.0     48.0      NaN      NaN
# 194   3      70.0       NaN      NaN     54.0     16.0      NaN      NaN
# 196   3     126.0      10.0      NaN    100.0     35.0      NaN      NaN
# 205   3     278.0      16.0      NaN    164.0    126.0      NaN      NaN
# 208   3     382.0      26.0      NaN    232.0    174.0      NaN      NaN
# 210   3     182.0      10.0      NaN    129.0     61.0      NaN      NaN
# 212   3     148.0       NaN      NaN     84.0     64.0      NaN      NaN
# 218   3     416.0      18.0      6.0    311.0    117.0      NaN      NaN
# 220   3     180.0       6.0      NaN    123.0     60.0      NaN      NaN
# 223   3     457.0      17.0      NaN    263.0    208.0      NaN      NaN
# 225   3     244.0      10.0      NaN    126.0    126.0      NaN      NaN
# 185   2     138.0      12.0      NaN    109.0     40.0      NaN      NaN
# 193   2      83.0       7.0      NaN     67.0     20.0      NaN      NaN
# 195   2     147.0      12.0      NaN    108.0     51.0      NaN      NaN
# 204   2     296.0      21.0      NaN    175.0    139.0      NaN      NaN
# 207   2     346.0      28.0      NaN    207.0    165.0      NaN      NaN
# 209   2     179.0       6.0      NaN    124.0     61.0      NaN      NaN
# 211   2     132.0       NaN      NaN     77.0     55.0      NaN      NaN
# 217   2     415.0      18.0      NaN    296.0    134.0      NaN      NaN
# 219   2     174.0       NaN      NaN    124.0     51.0      NaN      NaN
# 222   2     453.0      12.0      NaN    252.0    209.0      NaN      NaN
# 224   2     284.0       6.0      NaN    137.0    151.0      NaN      NaN
# 184   1     136.0       6.0      NaN     97.0     42.0      NaN      NaN
# 192   1      90.0       6.0      NaN     71.0     22.0      NaN      NaN
# 194   1     157.0       6.0      NaN    112.0     49.0      NaN      NaN
# 203   1     310.0      13.0      NaN    183.0    134.0      NaN      NaN
# 206   1     371.0      18.0      NaN    224.0    163.0      NaN      NaN
# 208   1     181.0      12.0      NaN    120.0     72.0      NaN      NaN
# 210   1     128.0       NaN      NaN     84.0     44.0      NaN      NaN
# 216   1     423.0      18.0      NaN    296.0    144.0      NaN      NaN
# 218   1     190.0       8.0      NaN    133.0     62.0      NaN      NaN
# 221   1     480.0      18.0      NaN    261.0    233.0      NaN      NaN
# 223   1     281.0       6.0      NaN    124.0    157.0      NaN      NaN
#
#      prenat1tot  prenat2tot  prenat3tot  prenat4tot  sex1tot  sex2tot  \
# 184         NaN         NaN         NaN         NaN    136.0    130.0
# 193         NaN         NaN         NaN         NaN     61.0     55.0
# 195         NaN         NaN         NaN         NaN     78.0     75.0
# 201         NaN         NaN         NaN         NaN    133.0    147.0
# 203         NaN         NaN         NaN         NaN    220.0    178.0
# 205         NaN         NaN         NaN         NaN    107.0    137.0
# 207         NaN         NaN         NaN         NaN     75.0     67.0
# 212         NaN         NaN         NaN         NaN    230.0    232.0
# 214         NaN         NaN         NaN         NaN    106.0    117.0
# 217         NaN         NaN         NaN         NaN    225.0    234.0
# 219         NaN         NaN         NaN         NaN    135.0    128.0
# 184         NaN         NaN         NaN         NaN    130.0    103.0
# 192         NaN         NaN         NaN         NaN     29.0     37.0
# 194         NaN         NaN         NaN         NaN     65.0     66.0
# 203         NaN         NaN         NaN         NaN    145.0    150.0
# 205         NaN         NaN         NaN         NaN    213.0    195.0
# 207         NaN         NaN         NaN         NaN    106.0    118.0
# 209         NaN         NaN         NaN         NaN     72.0     77.0
# 215         NaN         NaN         NaN         NaN    227.0    221.0
# 218         NaN         NaN         NaN         NaN     96.0    107.0
# 221         NaN         NaN         NaN         NaN    237.0    232.0
# 223         NaN         NaN         NaN         NaN    123.0    126.0
# 186         NaN         NaN         NaN         NaN     92.0     91.0
# 194         NaN         NaN         NaN         NaN     30.0     43.0
# 196         NaN         NaN         NaN         NaN     69.0     67.0
# 205         NaN         NaN         NaN         NaN    151.0    143.0
# 208         NaN         NaN         NaN         NaN    200.0    208.0
# 210         NaN         NaN         NaN         NaN     88.0    104.0
# 212         NaN         NaN         NaN         NaN     65.0     83.0
# 218         NaN         NaN         NaN         NaN    216.0    218.0
# 220         NaN         NaN         NaN         NaN     87.0     99.0
# 223         NaN         NaN         NaN         NaN    235.0    239.0
# 225         NaN         NaN         NaN         NaN    138.0    116.0
# 185        97.0        36.0        10.0         NaN     66.0     84.0
# 193        59.0        13.0         6.0         NaN     44.0     46.0
# 195        93.0        33.0        17.0         5.0     83.0     76.0
# 204       202.0        66.0        35.0         NaN    171.0    146.0
# 207       268.0        73.0        23.0         NaN    201.0    173.0
# 209       130.0        30.0        12.0         NaN     83.0    102.0
# 211        89.0        22.0        15.0         NaN     66.0     66.0
# 217       273.0        93.0        35.0         8.0    221.0    212.0
# 219       119.0        34.0        19.0         NaN     91.0     87.0
# 222       286.0       118.0        44.0         8.0    231.0    234.0
# 224       173.0        69.0        25.0        13.0    140.0    150.0
# 184        81.0        38.0        11.0         NaN     67.0     75.0
# 192        60.0        15.0         8.0         5.0     46.0     50.0
# 194       103.0        31.0        18.0         6.0     94.0     69.0
# 203       197.0        76.0        29.0         6.0    178.0    145.0
# 206       252.0        81.0        32.0         8.0    207.0    182.0
# 208       125.0        36.0        16.0         NaN     88.0    105.0
# 210        88.0        26.0         9.0         NaN     66.0     62.0
# 216       261.0        92.0        48.0         7.0    230.0    211.0
# 218       131.0        38.0        18.0         NaN     93.0    105.0
# 221       317.0       117.0        44.0         8.0    239.0    259.0
# 223       163.0        71.0        27.0        13.0    131.0    156.0
#
#          tract  weight1tot  weight2tot  weight3tot  weight4tot
# 184  1019000.0         NaN         NaN         NaN         NaN
# 193  1019800.0         NaN         NaN         NaN         NaN
# 195  1020000.0         NaN         NaN         NaN         NaN
# 201  1020800.0         NaN         NaN         NaN         NaN
# 203  1021000.0         NaN         NaN         NaN         NaN
# 205  1021200.0         NaN         NaN         NaN         NaN
# 207  1021400.0         NaN         NaN         NaN         NaN
# 212  1022000.0         NaN         NaN         NaN         NaN
# 214  1022200.0         NaN         NaN         NaN         NaN
# 217  1022400.0         NaN         NaN         NaN         NaN
# 219  1022600.0         NaN         NaN         NaN         NaN
# 184  1019000.0         NaN         NaN         NaN         NaN
# 192  1019800.0         NaN         NaN         NaN         NaN
# 194  1020000.0         NaN         NaN         NaN         NaN
# 203  1020800.0         NaN         NaN         NaN         NaN
# 205  1021000.0         NaN         NaN         NaN         NaN
# 207  1021200.0         NaN         NaN         NaN         NaN
# 209  1021400.0         NaN         NaN         NaN         NaN
# 215  1022000.0         NaN         NaN         NaN         NaN
# 218  1022200.0         NaN         NaN         NaN         NaN
# 221  1022400.0         NaN         NaN         NaN         NaN
# 223  1022600.0         NaN         NaN         NaN         NaN
# 186  1019000.0         NaN         NaN         NaN         NaN
# 194  1019800.0         NaN         NaN         NaN         NaN
# 196  1020000.0         NaN         NaN         NaN         NaN
# 205  1020800.0         NaN         NaN         NaN         NaN
# 208  1021000.0         NaN         NaN         NaN         NaN
# 210  1021200.0         NaN         NaN         NaN         NaN
# 212  1021400.0         NaN         NaN         NaN         NaN
# 218  1022000.0         NaN         NaN         NaN         NaN
# 220  1022200.0         NaN         NaN         NaN         NaN
# 223  1022400.0         NaN         NaN         NaN         NaN
# 225  1022600.0         NaN         NaN         NaN         NaN
# 185  1019000.0         7.0        60.0        29.0        46.0
# 193  1019800.0         7.0        35.0        22.0        21.0
# 195  1020000.0         8.0        79.0        30.0        38.0
# 204  1020800.0        24.0       131.0        73.0        82.0
# 207  1021000.0        17.0       137.0        97.0       114.0
# 209  1021200.0        11.0        84.0        42.0        44.0
# 211  1021400.0         5.0        62.0        35.0        28.0
# 217  1022000.0        23.0       195.0       105.0       100.0
# 219  1022200.0         NaN        84.0        45.0        38.0
# 222  1022400.0        26.0       208.0       111.0       103.0
# 224  1022600.0        23.0       111.0        66.0        85.0
# 184  1019000.0         5.0        56.0        27.0        46.0
# 192  1019800.0         6.0        39.0        23.0        23.0
# 194  1020000.0         9.0        81.0        29.0        36.0
# 203  1020800.0        22.0       138.0        82.0        70.0
# 206  1021000.0        20.0       149.0        97.0       114.0
# 208  1021200.0        13.0        70.0        48.0        56.0
# 210  1021400.0         6.0        51.0        34.0        35.0
# 216  1022000.0        21.0       200.0        98.0       110.0
# 218  1022200.0        10.0        93.0        47.0        37.0
# 221  1022400.0        29.0       216.0       107.0       130.0
# 223  1022600.0        21.0       110.0        68.0        80.0

# %%
# saving filtered data set as csv file (attached in email and on google shared drive [datakind/hcz])

########## raw_data_vsBirths.to_csv('/Users/cguy/Desktop/census_data/raw_data_vsBirths.csv')

# %%
##########
# Converting 'tract' to categorical type by converting value dtypes to string
    
########## raw_data_vsBirths['tract'] = raw_data_vsBirths['tract'].to_string(index=False)

raw_data_vsBirths.tract.apply('str')

# %%
from pandas_summary import DataFrameSummary

# Creating object to summarize dataframe

dfs = DataFrameSummary(raw_data_vsBirths)

# %%
with pd.option_context('display.max_rows', 2000, 'display.max_columns', 100):
   print(dfs.summary())
# Out:
#               age1tot  age2tot  age3tot  age4tot  age5tot  age6tot  age7tot  \
# count               0       28       50       55       55       55       55
# mean              NaN  13.3214     18.5  54.4545  61.0364  61.6727  42.7636
# std               NaN  8.52471  11.5728   35.511  30.9964  29.3567  17.4047
# min               NaN        5        5        6       11       19       10
# 25%               NaN        6     9.25       29       38       38     31.5
# 50%               NaN     10.5     15.5       42       51       60       38
# 75%               NaN     18.5    24.75       77     85.5       78       54
# max               NaN       34       52      143      119      137       89
# counts              0       28       50       55       55       55       55
# uniques             0       20       28       45       40       42       37
# missing            55       27        5        0        0        0        0
# missing_perc     100%   49.09%    9.09%       0%       0%       0%       0%
# types         numeric  numeric  numeric  numeric  numeric  numeric  numeric
#
#               age8tot   age9tot ancs10tot ancs11tot ancs12tot ancs13tot  \
# count              48         2         5        15         0         0
# mean          15.1667       5.5       7.2   6.06667       NaN       NaN
# std           6.92001  0.707107   2.38747   1.09978       NaN       NaN
# min                 5         5         5         5       NaN       NaN
# 25%                10      5.25         6         5       NaN       NaN
# 50%                14       5.5         6         6       NaN       NaN
# 75%             18.25      5.75         8         7       NaN       NaN
# max                37         6        11         8       NaN       NaN
# counts             48         2         5        15         0         0
# uniques            20         2         4         4         0         0
# missing             7        53        50        40        55        55
# missing_perc   12.73%    96.36%    90.91%    72.73%      100%      100%
# types         numeric      bool   numeric   numeric   numeric   numeric
#
#              ancs14tot ancs15tot ancs1tot ancs2tot ancs3tot ancs4tot ancs5tot  \
# count                4         1       55       48       43       26        9
# mean                 6         7    119.6  19.8958  23.6279  8.38462  5.77778
# std           0.816497       NaN  62.1803  15.0421  22.3458  3.18844  1.71594
# min                  5         7       27        5        5        5        5
# 25%               5.75         7     72.5     9.75        7     5.25        5
# 50%                  6         7      109     13.5       13        8        5
# 75%               6.25         7    161.5       26     35.5    10.75        5
# max                  7         7      268       61       85       15       10
# counts               4         1       55       48       43       26        9
# uniques              3         1       50       25       27        9        3
# missing             51        54        0        7       12       29       46
# missing_perc    92.73%    98.18%       0%   12.73%   21.82%   52.73%   83.64%
# types          numeric  constant  numeric  numeric  numeric  numeric  numeric
#
#               ancs6tot ancs7tot ancs8tot  ancs9tot ancs_oth_tot  apg1tot  \
# count                1       30        3         4           55       18
# mean                 5  11.5667  6.33333      7.25      69.5273  6.55556
# std                NaN  6.54788  1.52753  0.957427      36.8952  1.94701
# min                  5        5        5         6           16        5
# 25%                  5        6      5.5      6.75         44.5        5
# 50%                  5     10.5        6       7.5           63        6
# 75%                  5    14.75        7         8           93        7
# max                  5       28        8         8          158       11
# counts               1       30        3         4           55       18
# uniques              1       15        3         3           46        6
# missing             54       25       52        51            0       37
# missing_perc    98.18%   45.45%   94.55%    92.73%           0%   67.27%
# types         constant  numeric  numeric   numeric      numeric  numeric
#
#               apg2tot  apg3tot  apg4tot  apg5tot birthtot  bpl10tot bpl11tot  \
# count              16       50       55       30       55         1        0
# mean            6.875    16.82  228.964  11.8667  259.891         6      NaN
# std           1.62788  10.1854  110.734  5.68563  125.876       NaN      NaN
# min                 5        5       59        5       66         6      NaN
# 25%              5.75     8.25      139     7.25    151.5         6      NaN
# 50%                 7     13.5      217     10.5      233         6      NaN
# 75%                 8     23.5      340    15.75    381.5         6      NaN
# max                10       44      426       24      498         6      NaN
# counts             16       50       55       30       55         1        0
# uniques             5       28       53       14       53         1        0
# missing            39        5        0       25        0        54       55
# missing_perc   70.91%    9.09%       0%   45.45%       0%    98.18%     100%
# types         numeric  numeric  numeric  numeric  numeric  constant  numeric
#
#              bpl12tot bpl13tot bpl14tot  bpl15tot  bpl1tot  bpl2tot  bpl3tot  \
# count               0        2        0         1       55       32       22
# mean              NaN        6      NaN         7  166.618   20.125  7.90909
# std               NaN  1.41421      NaN       NaN  84.6171  16.3978  2.52434
# min               NaN        5      NaN         7       45        5        5
# 25%               NaN      5.5      NaN         7       99        7     6.25
# 50%               NaN        6      NaN         7      150       15      7.5
# 75%               NaN      6.5      NaN         7      244       31        8
# max               NaN        7      NaN         7      322       62       13
# counts              0        2        0         1       55       32       22
# uniques             0        2        0         1       51       22        7
# missing            55       53       55        54        0       23       33
# missing_perc     100%   96.36%     100%    98.18%       0%   41.82%      60%
# types         numeric     bool  numeric  constant  numeric  numeric  numeric
#
#               bpl4tot  bpl5tot  bpl6tot   bpl7tot  bpl8tot   bpl9tot  \
# count               3       19        4         1        5         2
# mean          7.33333  6.31579      8.5         5      7.8       5.5
# std           2.51661  1.73374  0.57735       NaN  1.92354  0.707107
# min                 5        5        8         5        5         5
# 25%                 6        5        8         5        7      5.25
# 50%                 7        5      8.5         5        8       5.5
# 75%               8.5        8        9         5        9      5.75
# max                10        9        9         5       10         6
# counts              3       19        4         1        5         2
# uniques             3        4        2         1        5         2
# missing            52       36       51        54       50        53
# missing_perc   94.55%   65.45%   92.73%    98.18%   90.91%    96.36%
# types         numeric  numeric     bool  constant  numeric      bool
#
#              bpl_oth_tot   bwt1tot  bwt2tot  bwt3tot  bwt4tot  bwt5tot  \
# count                 55         1       10       16       36       53
# mean             60.3091         5      6.8        7  8.08333  18.3019
# std              32.8385       NaN  1.54919   1.8619   2.6227  9.13696
# min                   12         5        5        5        5        5
# 25%                 35.5         5        6        5        6       11
# 50%                   50         5      6.5      6.5      7.5       15
# 75%                 82.5         5     7.75     8.25        9       28
# max                  132         5       10       10       14       38
# counts                55         1       10       16       36       53
# uniques               45         1        5        6       10       26
# missing                0        54       45       39       19        2
# missing_perc          0%    98.18%   81.82%   70.91%   34.55%    3.64%
# types            numeric  constant  numeric  numeric  numeric  numeric
#
#               bwt6tot  bwt7tot  bwt8tot  bwt9tot educ1tot educ2tot educ3tot  \
# count              55       55       55       53       22       22       22
# mean          57.5818  99.3455  56.7273  15.8491  75.9545  74.7273  103.455
# std           30.8267  48.9615  28.0934  6.51447  51.5535  43.3855  44.6657
# min                13       24       13        5       18       24       40
# 25%                35     62.5       32       11    34.25     41.5    75.25
# 50%                45       89       52       16     54.5       56     90.5
# 75%                80      137     73.5       21    114.5   106.25   129.25
# max               123      199      120       34      184      174      202
# counts             55       55       55       53       22       22       22
# uniques            39       47       44       23       18       21       20
# missing             0        0        0        2       33       33       33
# missing_perc       0%       0%       0%    3.64%      60%      60%      60%
# types         numeric  numeric  numeric  numeric  numeric  numeric  numeric
#
#              eth_ap_tot eth_bl_tot eth_hi_tot eth_wh_tot   ga1tot   ga2tot  \
# count                40         55         55         51       15       18
# mean              10.25    170.273    54.6727    24.8824  7.33333  8.11111
# std             4.92898    81.3491    42.0727    20.0546  2.09307  2.11128
# min                   5         41          9          5        5        5
# 25%                6.75      109.5       24.5         12        6     6.25
# 50%                 8.5        144         36         17        7        8
# 75%                  13        249       82.5         32      8.5     9.75
# max                  26        350        168        106       12       12
# counts               40         55         55         51       15       18
# uniques              14         51         43         31        7        8
# missing              15          0          0          4       40       37
# missing_perc     27.27%         0%         0%      7.27%   72.73%   67.27%
# types           numeric    numeric    numeric    numeric  numeric  numeric
#
#                ga3tot   ga4tot   ga5tot  mar1tot  mar2tot  mth1tot  mth2tot  \
# count              24       55       55       55       55       55       33
# mean          6.95833  19.4545  228.436  170.273  89.6182    171.4   9.0303
# std           2.17654  11.1252  110.522  99.0051  36.7441  85.7031  4.05035
# min                 5        5       54       35       31       43        5
# 25%                 5       10    137.5     98.5       64      101        5
# 50%                 6       17      210      128       85      146        8
# 75%              9.25       25    329.5      263    112.5      247       11
# max                11       49      430      388      196      366       20
# counts             24       55       55       55       55       55       33
# uniques             7       28       48       52       43       48       12
# missing            31        0        0        0        0        0       22
# missing_perc   56.36%       0%       0%       0%       0%       0%      40%
# types         numeric  numeric  numeric  numeric  numeric  numeric  numeric
#
#               mth3tot  mth4tot  nat1tot  nat2tot  par1tot  par2tot  pay1tot  \
# count              55       55       55       55       55       55       22
# mean          55.7636  26.1091  168.691  89.7273    121.2  138.473    177.5
# std           26.3993  14.4577  86.4478  46.3751  54.1631  74.6379  110.938
# min                13        7       45       21       39       26       48
# 25%              33.5       13     99.5     51.5     76.5     76.5     96.5
# 50%                56       26      150       77      112      115    119.5
# 75%                75       36    247.5      120      161    203.5      253
# max               109       69      328      185      234      302      427
# counts             55       55       55       55       55       55       22
# uniques            44       36       50       44       46       48       21
# missing             0        0        0        0        0        0       33
# missing_perc       0%       0%       0%       0%       0%       0%      60%
# types         numeric  numeric  numeric  numeric  numeric  numeric  numeric
#
#               pay2tot  pay3tot       pd plur1tot plur2tot  pob1tot  pob2tot  \
# count              22        5       55       55       46        5       55
# mean          74.7273        7        3  248.745  13.0217      5.8  162.309
# std           31.5144        1  1.42725  120.589   6.1409  1.30384  74.5353
# min                39        6        1       65        6        5       50
# 25%                57        6        2    147.5        8        5    108.5
# 50%              64.5        7        3      223       12        5      137
# 75%                82        8        4    358.5       18        6    215.5
# max               155        8        5      480       28        8      338
# counts             22        5       55       55       46        5       55
# uniques            19        3        5       54       17        3       50
# missing            33       50        0        0        9       50        0
# missing_perc      60%   90.91%       0%       0%   16.36%   90.91%       0%
# types         numeric  numeric  numeric  numeric  numeric  numeric  numeric
#
#               pob3tot  pob4tot  pob5tot prenat1tot prenat2tot prenat3tot  \
# count              55        0        0         22         22         22
# mean               95      NaN      NaN    162.136    54.9091    22.7727
# std           59.1796      NaN      NaN    81.6072    31.8925    12.5164
# min                15      NaN      NaN         59         13          6
# 25%                51      NaN      NaN         94       31.5      12.75
# 50%                71      NaN      NaN      130.5         38       18.5
# 75%             136.5      NaN      NaN      239.5      75.25      31.25
# max               233      NaN      NaN        317        118         48
# counts             55        0        0         22         22         22
# uniques            44        0        0         22         20         19
# missing             0       55       55         33         33         33
# missing_perc       0%     100%     100%        60%        60%        60%
# types         numeric  numeric  numeric    numeric    numeric    numeric
#
#              prenat4tot  sex1tot  sex2tot     tract weight1tot weight2tot  \
# count                11       55       55       NaN         21         22
# mean            7.90909  130.109  129.782       NaN    14.9048    108.591
# std             2.77325  65.2144  61.5542       NaN    8.04925    56.2762
# min                   5       29       37       NaN          5         35
# 25%                   6     76.5     76.5       NaN          7         64
# 50%                   8      107      117       NaN         13       88.5
# 75%                   8    200.5    175.5       NaN         22     137.75
# max                  13      239      259       NaN         29        216
# counts               11       55       55        55         21         22
# uniques               5       48       48         1         16         21
# missing              44        0        0         0         34         33
# missing_perc        80%       0%       0%        0%     61.82%        60%
# types           numeric  numeric  numeric  constant    numeric    numeric
#
#              weight3tot weight4tot
# count                22         22
# mean            59.7727    65.2727
# std             31.3626    34.4718
# min                  22         21
# 25%                  31      37.25
# 50%                47.5         51
# 75%               93.25      96.25
# max                 111        130
# counts               22         22
# uniques              20         19
# missing              33         33
# missing_perc        60%        60%
# types           numeric    numeric

# %%
dfs.columns_types
# Out:
# numeric     89
# constant     7
# bool         4
# Name: types, dtype: int64

# %%
# looking at one column (age8tot) randomly, in detail
# RECOMMENDED FUTURE STEP: For future analysis, should complete thorough EDA, 
# including utilization of this object property for each column in data set

dfs['age8tot']
# Out:
# /Users/cguy/anaconda3/lib/python3.6/site-packages/pandas_summary/__init__.py:130: RuntimeWarning: invalid value encountered in minimum
#   capped_series = np.minimum(series, series.mean() + multiplier * series.std())
# /Users/cguy/anaconda3/lib/python3.6/site-packages/pandas_summary/__init__.py:143: RuntimeWarning: invalid value encountered in minimum
#   capped_series = np.minimum(series, series.median() + multiplier * series.mad())
# mean                                                                 15.1667
# std                                                                  6.92001
# variance                                                             47.8865
# min                                                                        5
# max                                                                       37
# 5%                                                                      5.35
# 25%                                                                       10
# 50%                                                                       14
# 75%                                                                    18.25
# 95%                                                                    25.95
# iqr                                                                     8.25
# kurtosis                                                             1.81607
# skewness                                                             1.03382
# sum                                                                      728
# mad                                                                  5.23611
# cv                                                                  0.456264
# zeros_num                                                                  0
# zeros_perc                                                                0%
# deviating_of_mean                                                          8
# deviating_of_mean_perc                                                14.55%
# deviating_of_median                                                        9
# deviating_of_median_perc                                              16.36%
# top_correlations            age9tot: 100%, bpl13tot: -100%, ancs8tot: 99.98%
# counts                                                                    48
# uniques                                                                   20
# missing                                                                    7
# missing_perc                                                          12.73%
# types                                                                numeric
# Name: age8tot, dtype: object

# %%
dfs['tract']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-cc1c855833a1> in <module>()
# ----> 1 dfs['tract']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas_summary/__init__.py in __getitem__(self, column)
#      30     def __getitem__(self, column):
#      31         if isinstance(column, str) and self._clean_column(column):
# ---> 32             return self._get_column_summary(column)
#      33
#      34         if isinstance(column, int) and column < self.df.shape[1]:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas_summary/__init__.py in _get_column_summary(self, column)
#     235             return self._get_date_summary(column)
#     236         if column_type == self.TYPE_CONSTANT:
# --> 237             return self._get_constant_summary(column)
#     238
#     239     def get_columns(self, df, usage, columns=None):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas_summary/__init__.py in _get_constant_summary(self, column)
#     206
#     207     def _get_constant_summary(self, column):
# --> 208         return 'This is a constant value: {}'.format(self.df[column][0])
#     209
#     210     def _get_bool_summary(self, column):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 0

# %%
dfs['pd']
# Out:
# mean                                                                     3
# std                                                                1.42725
# variance                                                           2.03704
# min                                                                      1
# max                                                                      5
# 5%                                                                       1
# 25%                                                                      2
# 50%                                                                      3
# 75%                                                                      4
# 95%                                                                      5
# iqr                                                                      2
# kurtosis                                                          -1.30885
# skewness                                                                 0
# sum                                                                    165
# mad                                                                    1.2
# cv                                                                0.475749
# zeros_num                                                                0
# zeros_perc                                                              0%
# deviating_of_mean                                                        0
# deviating_of_mean_perc                                                  0%
# deviating_of_median                                                      0
# deviating_of_median_perc                                                0%
# top_correlations            bpl9tot: -100%, age9tot: 100%, bpl13tot: -100%
# counts                                                                  55
# uniques                                                                  5
# missing                                                                  0
# missing_perc                                                            0%
# types                                                              numeric
# Name: pd, dtype: object

# %%
dfs['birthtot']
# Out:
# mean                                                               259.891
# std                                                                125.876
# variance                                                           15844.9
# min                                                                     66
# max                                                                    498
# 5%                                                                    94.2
# 25%                                                                  151.5
# 50%                                                                    233
# 75%                                                                  381.5
# 95%                                                                  466.2
# iqr                                                                    230
# kurtosis                                                          -1.09193
# skewness                                                          0.439427
# sum                                                                  14294
# mad                                                                106.822
# cv                                                                0.484343
# zeros_num                                                                0
# zeros_perc                                                              0%
# deviating_of_mean                                                        0
# deviating_of_mean_perc                                                  0%
# deviating_of_median                                                      0
# deviating_of_median_perc                                                0%
# top_correlations            bpl9tot: -100%, age9tot: 100%, bpl13tot: -100%
# counts                                                                  55
# uniques                                                                 53
# missing                                                                  0
# missing_perc                                                            0%
# types                                                              numeric
# Name: birthtot, dtype: object

# %%
raw_data_vsBirths.columns
# Out:
# Index(['age1tot', 'age2tot', 'age3tot', 'age4tot', 'age5tot', 'age6tot',
#        'age7tot', 'age8tot', 'age9tot', 'ancs10tot', 'ancs11tot', 'ancs12tot',
#        'ancs13tot', 'ancs14tot', 'ancs15tot', 'ancs1tot', 'ancs2tot',
#        'ancs3tot', 'ancs4tot', 'ancs5tot', 'ancs6tot', 'ancs7tot', 'ancs8tot',
#        'ancs9tot', 'ancs_oth_tot', 'apg1tot', 'apg2tot', 'apg3tot', 'apg4tot',
#        'apg5tot', 'birthtot', 'bpl10tot', 'bpl11tot', 'bpl12tot', 'bpl13tot',
#        'bpl14tot', 'bpl15tot', 'bpl1tot', 'bpl2tot', 'bpl3tot', 'bpl4tot',
#        'bpl5tot', 'bpl6tot', 'bpl7tot', 'bpl8tot', 'bpl9tot', 'bpl_oth_tot',
#        'bwt1tot', 'bwt2tot', 'bwt3tot', 'bwt4tot', 'bwt5tot', 'bwt6tot',
#        'bwt7tot', 'bwt8tot', 'bwt9tot', 'educ1tot', 'educ2tot', 'educ3tot',
#        'eth_ap_tot', 'eth_bl_tot', 'eth_hi_tot', 'eth_wh_tot', 'ga1tot',
#        'ga2tot', 'ga3tot', 'ga4tot', 'ga5tot', 'mar1tot', 'mar2tot', 'mth1tot',
#        'mth2tot', 'mth3tot', 'mth4tot', 'nat1tot', 'nat2tot', 'par1tot',
#        'par2tot', 'pay1tot', 'pay2tot', 'pay3tot', 'pd', 'plur1tot',
#        'plur2tot', 'pob1tot', 'pob2tot', 'pob3tot', 'pob4tot', 'pob5tot',
#        'prenat1tot', 'prenat2tot', 'prenat3tot', 'prenat4tot', 'sex1tot',
#        'sex2tot', 'tract', 'weight1tot', 'weight2tot', 'weight3tot',
#        'weight4tot'],
#       dtype='object')

# %% [markdown]
# ## NOTES ABOUT DATA SET & MODEL DEVELOPMENT PLAN
#
# - As seen above, the data set contains a ___significant___ amount of NaNs in several columns.
# - Considering the fact that the value 0.0 (zero) exists in the data set, I am making the assumption that NaNs represent missing data.
# - Dropping rows with NaNs will decrease an already sparse data set.
# - High Dimensionality (lots of columns/features)
# - Categorical data has already been encoded (except for the 'pd' column that I added earlier to indicate time frame).
#
# - Considering notes above, I will complete the following plan:
#
#     (A) Drop 'tract' column -- no significance
#
#     (B) Drop any columns with 100% missing data -- to help reduce # of features
#
#     (C) Encode 'pd' column -- using one hot encoder/get dummies/indicator variables
#
#     (D) Address Missing Data:
#
#      - Create 2 data sets:
#
#      (1) ZoneData_imputed0: Missing values imputed with 0 (zero)
#
#      (2) ZoneData_imputedMean: Missing values imputed with mean
#
#       __NOTE__: Future analysis should refer to skewness, etc. of column and impute values with median/mean/mode depending on descriptive stats. Check this link out for a good reference, if needed: https://machinelearningmastery.com/handle-missing-data-python/
#
#   (E) Build and evaluate the following model on the 2 data sets:
#
#      - Lasso Least Angle Regression (Documentation: http://scikit-learn.org/stable/modules/linear_model.html#least-angle-regression)
#
#      - Pros of the LARS method include (from documentation):
#        - It is numerically efficient when the number of dimensions is significantly greater than the number of points
#        - It is computationally just as fast as forward selection and has the same order of complexity as an ordinary least squares.
#        - It produces a full piecewise linear solution path, which is useful in cross-validation or similar attempts to tune the model.
#        - If two variables are almost equally correlated with the response, then their coefficients should increase at approximately the same rate. The algorithm thus behaves as intuition would expect, and also is more stable.
#
#      - Cons of the LARS method include (from documentation):
#        - Because LARS is based upon an iterative refitting of the residuals, it would appear to be especially sensitive to the effects of noise.
#
#      __NOTE__: Future model development/evaluation should include standardization steps. See recommended documentation here: http://blog.minitab.com/blog/adventures-in-statistics-2/what-are-the-effects-of-multicollinearity-and-when-can-i-ignore-them
#
#   (F) Pick best performing model and then Pickle Model for future use

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
# (A) Drop 'tract' column -- no significance

########## raw_data_vsBirths = raw_data_vsBirths.drop('tract', axis=1)

# %%
# (B) Drop any columns with 100% missing data -- to help reduce # of features

########## raw_data_vsBirths = raw_data_vsBirths.drop(['age1tot', 'ancs12tot', 'ancs13tot', 'bpl11tot', \
##########                                            'bpl12tot', 'bpl14tot', 'pob4tot', 'pob5tot'], axis=1)

raw_data_vsBirths = result.drop(['age1tot', 'ancs12tot', 'ancs13tot', 'bpl11tot', \
                                            'bpl12tot', 'bpl14tot', 'pob4tot', 'pob5tot'], axis=1)

# %%
##########

# (C) Encode 'pd' column

########## encoded_pd_col = pd.get_dummies(raw_data_vsBirths['pd'])
########## raw_data_vsBirths = pd.concat([encoded_pd_col, raw_data_vsBirths], axis=1)

#dropping original 'pd' column
########## raw_data_vsBirths = raw_data_vsBirths.drop('pd', axis=1)
########## raw_data_vsBirths.columns

# %%
########## Variables of interest

Vars = raw_data_vsBirths[['tract','pd','birthtot']]
Vars_train_cv = Vars[Vars['pd'] != 5]
Vars_train_cv.head()
# Out:
#        tract  pd  birthtot
# 0  1000201.0   4     272.0
# 1  1000202.0   4     421.0
# 2  1000600.0   4    1223.0
# 3  1000700.0   4     355.0
# 4  1000800.0   4    1722.0

# %%
Vars_test = Vars[Vars['pd'] == 5]
Vars_test.head()
# Out:
#        tract  pd  birthtot
# 0  1000201.0   5     202.0
# 1  1000202.0   5     388.0
# 2  1000600.0   5     852.0
# 3  1000700.0   5     551.0
# 4  1000800.0   5    1130.0

# %%
##########
# (D) Address Missing Data:

# Create 2 data sets:
    
# (1) ZoneData_imputed0: Missing values imputed with 0 (zero)
    
########## ZoneData_imputed0 = raw_data_vsBirths.fillna(value=0)
    
# (2) ZoneData_imputedMean: Missing values imputed with mean
    
########## ZoneData_imputedMean = raw_data_vsBirths.fillna(raw_data_vsBirths.mean())

# %%
##########
# (E) Build and evaluate the following model on the 2 data sets: Lasso Least Angle Regression

# # (1) ZoneData_imputed0, using LassoLarsCV (cross-validation)

# Setting X and Y (features and target data)

########## X_imputeZero = ZoneData_imputed0.drop('birthtot', axis = 1)
########## Y_imputeZero = ZoneData_imputed0['birthtot']

X_imputeZero = Vars_train_cv.drop('birthtot', axis = 1)
Y_imputeZero = Vars_train_cv['birthtot']

# #############################################################################
# LassoLarsCV: least angle regression

# Compute paths
print("Computing regularization path using the Lars lasso...")
t1 = time.time()

# Fit model on training data using LassoLarsCV

model_imputeZero = LassoLarsCV(cv=4).fit(X_imputeZero, Y_imputeZero)

t_lasso_lars_cv = time.time() - t1

# Display results of alphas
m_log_alphas = -np.log10(model_imputeZero.cv_alphas_)

plt.figure(figsize=(10,10))
ymin, ymax = 20000, 20000
plt.plot(m_log_alphas, model_imputeZero.mse_path_, ':')
plt.plot(m_log_alphas, model_imputeZero.mse_path_.mean(axis=-1), 'k',
         label='Average across the folds', linewidth=2)
plt.axvline(-np.log10(model_imputeZero.alpha_), linestyle='--', color='k',
            label='alpha CV')
plt.legend()

plt.xlabel('-log(alpha)')
plt.ylabel('Mean square error')
plt.title('Mean square error on each fold: Lars (train time: %.2fs)'
          % t_lasso_lars_cv)
plt.axis('tight')
plt.ylim(ymin, ymax)
# Out:
# Computing regularization path using the Lars lasso...
# /Users/cguy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in log10
# /Users/cguy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in log10
# /Users/cguy/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3239: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=20000, top=20000
#   'bottom=%s, top=%s') % (bottom, top))
# (19980.0, 20020.0)

# %%
model_imputeZero.get_params
# Out:
# <bound method BaseEstimator.get_params of LassoLarsCV(copy_X=True, cv=4, eps=2.2204460492503131e-16, fit_intercept=True,
#       max_iter=500, max_n_alphas=1000, n_jobs=1, normalize=True,
#       positive=False, precompute='auto', verbose=False)>

# %%
# Scoring model on 'test' data
# Using subset of data (2010 - 2014) to test/score model
# However, need to use real test data when new data is available

X_test = Vars_test.drop('birthtot', axis = 1)
y_test = Vars_test['birthtot']

model_imputeZero.score(X_test, y_test)
# Out:
# 0.04542932003986988

# %%
X_test
# Out:
#           tract  pd
# 0     1000201.0   5
# 1     1000202.0   5
# 2     1000600.0   5
# 3     1000700.0   5
# 4     1000800.0   5
# 5     1000900.0   5
# 6     1001001.0   5
# 7     1001002.0   5
# 8     1001200.0   5
# 9     1001300.0   5
# 10    1001401.0   5
# 11    1001402.0   5
# 12    1001501.0   5
# 13    1001502.0   5
# 14    1001600.0   5
# 15    1001800.0   5
# 16    1002000.0   5
# 17    1002100.0   5
# 18    1002201.0   5
# 19    1002202.0   5
# 20    1002400.0   5
# 21    1002500.0   5
# 22    1002601.0   5
# 23    1002602.0   5
# 24    1002700.0   5
# 25    1002800.0   5
# 26    1002900.0   5
# 27    1003001.0   5
# 28    1003002.0   5
# 29    1003100.0   5
# ...         ...  ..
# 2031  5020100.0   5
# 2032  5020700.0   5
# 2033  5020801.0   5
# 2034  5020803.0   5
# 2035  5020804.0   5
# 2036  5021300.0   5
# 2037  5022300.0   5
# 2038  5022600.0   5
# 2039  5023100.0   5
# 2040  5023900.0   5
# 2041  5024401.0   5
# 2042  5024402.0   5
# 2043  5024700.0   5
# 2044  5024800.0   5
# 2045  5025100.0   5
# 2046  5027301.0   5
# 2047  5027302.0   5
# 2048  5027702.0   5
# 2049  5027704.0   5
# 2050  5027705.0   5
# 2051  5027706.0   5
# 2052  5027900.0   5
# 2053  5029102.0   5
# 2054  5029103.0   5
# 2055  5029104.0   5
# 2056  5030301.0   5
# 2057  5030302.0   5
# 2058  5031901.0   5
# 2059  5031902.0   5
# 2060  5032300.0   5
#
# [2061 rows x 2 columns]

# %%
df_predict_X = pd.DataFrame(zone_census_tracts, columns=['tract'])
df_predict_X['pd'] ='7'
df_predict_X.head()
# Out:
#      tract pd
# 0  1019000  7
# 1  1019800  7
# 2  1020000  7
# 3  1020800  7
# 4  1021000  7

# %%
model_imputeZero.predict(df_predict_X)
# Out:
# array([ 375.62707703,  375.59375133,  375.58541991,  375.55209421,
#         375.54376279,  375.53543137,  375.52709994,  375.50210567,
#         375.49377425,  375.48544282,  375.4771114 ])

# %% [markdown]
# ---------------------

# %%
# (E) Build and evaluate the following model on the 2 data sets: Lasso Least Angle Regression

# # (1) ZoneData_imputedMean, using LassoLarsCV (cross-validation)

# Setting X and Y (features and target data)

X_imputeMean = ZoneData_imputedMean.drop('birthtot', axis = 1)
Y_imputeMean = ZoneData_imputedMean['birthtot']

# #############################################################################
# LassoLarsCV: least angle regression

# Compute paths
print("Computing regularization path using the Lars lasso...")
t1 = time.time()

# Fit model on training data using LassoLarsCV

model_imputeMean = LassoLarsCV(cv=4).fit(X_imputeMean, Y_imputeMean)

t_lasso_lars_cv = time.time() - t1

# Display results of alphas
m_log_alphas = -np.log10(model_imputeMean.cv_alphas_)

plt.figure(figsize=(10,10))
ymin, ymax = 0, 1000
plt.plot(m_log_alphas, model_imputeMean.mse_path_, ':')
plt.plot(m_log_alphas, model_imputeMean.mse_path_.mean(axis=-1), 'k',
         label='Average across the folds', linewidth=2)
plt.axvline(-np.log10(model_imputeMean.alpha_), linestyle='--', color='k',
            label='alpha CV')
plt.legend()

plt.xlabel('-log(alpha)')
plt.ylabel('Mean square error')
plt.title('Mean square error on each fold: Lars (train time: %.2fs)'
          % t_lasso_lars_cv)
plt.axis('tight')
plt.ylim(ymin, ymax)

# %%
model_imputeMean.get_params

# %%
# Scoring model on 'test' data
# Using subset of data (2010 - 2014) to test/score model
# However, need to use real test data when new data is available

y_test = ZoneData_imputedMean[ZoneData_imputedMean[1014]==1]
y_test = y_test['birthtot']
X_test = X_imputeMean[X_imputeMean[1014]==1]

model_imputeMean.score(X_test, y_test)

# %% [markdown]
# ## NOTES ON MODELS
#
# #### R^2 scores are 1.0 for both models because not using actual test (unseen) data to score.
# #### Need to re-do when new data available to use as test data.

# %%
# (F) Pickle Model (great resource for pickle steps: 
#                   https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/)

# Pickling models to share

from sklearn.externals import joblib

try:
   import cPickle as pickle
except:
   import pickle

# save the model to disk
# They are also attached in email and on shared drive [datakind/hcz]
filename_1 = '/Users/cguy/Desktop/census_data/HCZ_births_finalized_model_imputeZero.pkl'
filename_2 = '/Users/cguy/Desktop/census_data/HCZ_births_finalized_model_imputeMean.pkl'

joblib.dump(model_imputeZero, filename_1)
joblib.dump(model_imputeMean, filename_2)

# %%
# To access pickled model...
 
# load the model from disk
loaded_model = joblib.load(filename_1)
result = loaded_model.score(X_test, y_test)
print(result)

# %%
loaded_model.predict(X_test)

# %%
model_imputeZero.predict(df_predict_X)
# Out:
# array([ 375.62707703,  375.59375133,  375.58541991,  375.55209421,
#         375.54376279,  375.53543137,  375.52709994,  375.50210567,
#         375.49377425,  375.48544282,  375.4771114 ])

# %%
####### total_births_in_the_Zone_based_on_census_tracts = np.sum(loaded_model.predict(X_test))

# %%
total_births_in_the_Zone_based_on_census_tracts = np.sum(model_imputeZero.predict(df_predict_X))

# %%
total_births_in_the_Zone_based_on_census_tracts
# Out:
# 4130.9230707132274
